# %% [markdown]
# # Data collection

# %% [markdown]
# Data collection is the systematic approach to gathering and measuring information from a variety of sources to get a complete and accurate picture of an area of interest. Data collection enables a person or organization to answer relevant questions, evaluate outcomes and make predictions about future probabilities and trends.

# %% [markdown]
# ### Data collection methods

# %% [markdown]
# Surveys, interviews and focus groups are primary instruments for collecting information. Today, with help from Web and analytics tools, organizations are also able to collect data from mobile devices, website traffic, server activity and other relevant sources, depending on the project.

# %% [markdown]
# There are also some other indirect sources for collecting data. Such sources are called as secondary data sources. For example, government collects census but the data collected is open for anyone to use.

# %% [markdown]
# ### Big data and data collection

# %% [markdown]
# Big data describes voluminous amounts of structured, semi-structured and unstructured data collected by organizations. But because it takes a lot of time and money to load big data into a traditional relational database for analysis, new approaches for collecting and analyzing data have emerged. To gather and then mine big data for information, data is stored at place with the relevant tags( data lake). From there, machine learning and artificial intelligence programs use complex algorithms to look for repeatable patterns.

# %% [markdown]
# ### Types of data

# %% [markdown]
# Generally, there are two types of data: quantitative data and qualitative data.

# %% [markdown]
# Quantitative data is any data that is in numerical form
# - such as statistics and percentages.

# %% [markdown]
# Qualitative data is descriptive data
# - such as color, smell, appearance and quality

# %% [markdown]
# ### Qualitative data vs Quantitative data

# %% [markdown]
# To get a better understanding about the differences between qualitative and quantitative data let us put them into tabular form. After all, that is what data visualisation is.

# %%
from IPython.display import Image
Image('http://s3.amazonaws.com/libapps/accounts/732/images/quantitative_vs_qualitative.jpg')
